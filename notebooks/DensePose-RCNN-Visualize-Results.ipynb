# %%
import numpy
import cv2
import matplotlib.pyplot as plt
import numpy as np

im  = cv2.imread('../DensePoseData/demo_data/demo_im2.jpg')
IUV = cv2.imread('../DensePoseData/infer_out/demo_im2_IUV.png')
INDS = cv2.imread('../DensePoseData/infer_out/demo_im2_INDS.png',  0)

# %% [markdown]
# Let's visualize the I, U and V images.

# %%
fig = plt.figure(figsize=[15,15])
plt.imshow(   np.hstack((IUV[:,:,0]/24. ,IUV[:,:,1]/256. ,IUV[:,:,2]/256.))  )
plt.title('I, U and V images.')
plt.axis('off') ; plt.show()

# %% [markdown]
# Let's visualize the isocontours of the UV fields.

# %%
fig = plt.figure(figsize=[12,12])
plt.imshow( im[:,:,::-1] )
plt.contour( IUV[:,:,1]/256.,10, linewidths = 1 )
plt.contour( IUV[:,:,2]/256.,10, linewidths = 1 )
plt.axis('off') ; plt.show()

# %% [markdown]
# Let's visualize the human-body FG mask indices.

# %%
fig = plt.figure(figsize=[12,12])
plt.imshow( im[:,:,::-1] )
plt.contour( INDS, linewidths = 4 )
plt.axis('off') ; plt.show()
# Out:
# /home/yym/.local/lib/python2.7/site-packages/matplotlib-2.2.2-py2.7-linux-x86_64.egg/matplotlib/contour.py:1173: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"
